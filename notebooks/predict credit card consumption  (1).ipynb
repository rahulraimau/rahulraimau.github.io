# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy import stats
from scipy.stats import norm, skew
# %matplotlib inline

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


# from sklearn.linear_model import LinearRegression
# sklearn - scikit learn

# %%
def continuous_var_summary( x ):
    
    # freq and missings
    n_total = x.shape[0]
    n_miss = x.isna().sum()
    perc_miss = n_miss * 100 / n_total
    
    # outliers - iqr
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    lc_iqr = q1 - 1.5 * iqr
    uc_iqr = q3 + 1.5 * iqr
    
    
    return pd.Series( [ x.dtype, x.nunique(), n_total, x.count(), n_miss, perc_miss,
                       x.sum(), x.mean(), x.std(), x.var(), 
                       lc_iqr, uc_iqr, 
                       x.min(), x.quantile(0.01), x.quantile(0.05), x.quantile(0.10), 
                       x.quantile(0.25), x.quantile(0.5), x.quantile(0.75), 
                       x.quantile(0.90), x.quantile(0.95), x.quantile(0.99), x.max() ], 
                      
                    index = ['dtype', 'cardinality', 'n_tot', 'n', 'nmiss', 'perc_miss',
                             'sum', 'mean', 'std', 'var',
                        'lc_iqr', 'uc_iqr',
                        'min', 'p1', 'p5', 'p10', 'p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'max'])

# %%
# Create Data audit Report for categorical variables
def categorical_var_summary( x ):
    Mode = x.value_counts().sort_values(ascending = False)[0:1].reset_index()
    return pd.Series([x.count(), x.isnull().sum(), Mode.iloc[0, 0], Mode.iloc[0, 1], 
                          round(Mode.iloc[0, 1] * 100 / x.count(), 2)], 
                     
                  index = ['N', 'NMISS', 'MODE', 'FREQ', 'PERCENT'])

# %%
# Missing value imputation for continuous variables
def missing_imputation( x, stats = 'mean' ):
    if (x.dtypes == 'float64') | (x.dtypes == 'int64'):
        x = x.fillna(x.mean()) if stats == 'mean' else x.fillna(x.median())
    return x

# %%
# An utility function to create dummy variable
def create_dummies(df, colname):
    col_dummies = pd.get_dummies(df[colname], prefix = colname, drop_first = True)
    df = pd.concat([df, col_dummies], axis = 1)
    df.drop(colname, axis = 1, inplace = True )
    return df

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
creditConsumptionData = pd.read_excel(r"C:\Users\Dell\Downloads\New folder (2)\CreditConsumptionData.xlsx")

# %%
CustomerBehaviorData = pd.read_excel(r"C:\Users\Dell\Downloads\New folder (2)\CustomerBehaviorData.xlsx")

# %%
CustomerDemographics = pd.read_excel(r"C:\Users\Dell\Downloads\New folder (2)\CustomerDemographics.xlsx")

# %%
creditConsumptionData .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       20000 non-null  int64
#  1   cc_cons  15000 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 312.6 KB

# %%
CustomerBehaviorData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     20000 non-null  int64
#  1   cc_cons_apr            20000 non-null  float64
#  2   dc_cons_apr            20000 non-null  float64
#  3   cc_cons_may            19999 non-null  float64
#  4   dc_cons_may            20000 non-null  float64
#  5   cc_cons_jun            20000 non-null  float64
#  6   dc_cons_jun            19999 non-null  float64
#  7   cc_count_apr           19999 non-null  float64
#  8   cc_count_may           20000 non-null  int64
#  9   cc_count_jun           20000 non-null  int64
#  10  dc_count_apr           20000 non-null  int64
#  11  dc_count_may           20000 non-null  int64
#  12  dc_count_jun           20000 non-null  int64
#  13  card_lim               20000 non-null  int64
#  14  personal_loan_active   20000 non-null  int64
#  15  vehicle_loan_active    20000 non-null  int64
#  16  personal_loan_closed   19999 non-null  float64
#  17  vehicle_loan_closed    20000 non-null  int64
#  18  investment_1           20000 non-null  float64
#  19  investment_2           20000 non-null  float64
#  20  investment_3           19998 non-null  float64
#  21  investment_4           20000 non-null  float64
#  22  debit_amount_apr       20000 non-null  float64
#  23  credit_amount_apr      20000 non-null  float64
#  24  debit_count_apr        19999 non-null  float64
#  25  credit_count_apr       20000 non-null  int64
#  26  max_credit_amount_apr  20000 non-null  float64
#  27  debit_amount_may       20000 non-null  float64
#  28  credit_amount_may      20000 non-null  float64
#  29  credit_count_may       20000 non-null  int64
#  30  debit_count_may        20000 non-null  int64
#  31  max_credit_amount_may  20000 non-null  float64
#  32  debit_amount_jun       20000 non-null  float64
#  33  credit_amount_jun      20000 non-null  float64
#  34  credit_count_jun       20000 non-null  int64
#  35  debit_count_jun        20000 non-null  int64
#  36  max_credit_amount_jun  20000 non-null  float64
#  37  loan_enq               19998 non-null  object
#  38  emi_active             19999 non-null  float64
# dtypes: float64(23), int64(15), object(1)
# memory usage: 6.0+ MB

# %%
CustomerDemographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  int64
#  1   account_type                  19999 non-null  object
#  2   gender                        19999 non-null  object
#  3   age                           20000 non-null  int64
#  4   Income                        19999 non-null  object
#  5   Emp_Tenure_Years              20000 non-null  float64
#  6   Tenure_with_Bank              20000 non-null  int64
#  7   region_code                   19999 non-null  float64
#  8   NetBanking_Flag               20000 non-null  int64
#  9   Avg_days_between_transaction  19997 non-null  float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 1.5+ MB

# %%
df1 = pd.merge(creditConsumptionData,CustomerBehaviorData)
df = pd.merge(df1,CustomerDemographics)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  int64
#  1   cc_cons                       15000 non-null  float64
#  2   cc_cons_apr                   20000 non-null  float64
#  3   dc_cons_apr                   20000 non-null  float64
#  4   cc_cons_may                   19999 non-null  float64
#  5   dc_cons_may                   20000 non-null  float64
#  6   cc_cons_jun                   20000 non-null  float64
#  7   dc_cons_jun                   19999 non-null  float64
#  8   cc_count_apr                  19999 non-null  float64
#  9   cc_count_may                  20000 non-null  int64
#  10  cc_count_jun                  20000 non-null  int64
#  11  dc_count_apr                  20000 non-null  int64
#  12  dc_count_may                  20000 non-null  int64
#  13  dc_count_jun                  20000 non-null  int64
#  14  card_lim                      20000 non-null  int64
#  15  personal_loan_active          20000 non-null  int64
#  16  vehicle_loan_active           20000 non-null  int64
#  17  personal_loan_closed          19999 non-null  float64
#  18  vehicle_loan_closed           20000 non-null  int64
#  19  investment_1                  20000 non-null  float64
#  20  investment_2                  20000 non-null  float64
#  21  investment_3                  19998 non-null  float64
#  22  investment_4                  20000 non-null  float64
#  23  debit_amount_apr              20000 non-null  float64
#  24  credit_amount_apr             20000 non-null  float64
#  25  debit_count_apr               19999 non-null  float64
#  26  credit_count_apr              20000 non-null  int64
#  27  max_credit_amount_apr         20000 non-null  float64
#  28  debit_amount_may              20000 non-null  float64
#  29  credit_amount_may             20000 non-null  float64
#  30  credit_count_may              20000 non-null  int64
#  31  debit_count_may               20000 non-null  int64
#  32  max_credit_amount_may         20000 non-null  float64
#  33  debit_amount_jun              20000 non-null  float64
#  34  credit_amount_jun             20000 non-null  float64
#  35  credit_count_jun              20000 non-null  int64
#  36  debit_count_jun               20000 non-null  int64
#  37  max_credit_amount_jun         20000 non-null  float64
#  38  loan_enq                      19998 non-null  object
#  39  emi_active                    19999 non-null  float64
#  40  account_type                  19999 non-null  object
#  41  gender                        19999 non-null  object
#  42  age                           20000 non-null  int64
#  43  Income                        19999 non-null  object
#  44  Emp_Tenure_Years              20000 non-null  float64
#  45  Tenure_with_Bank              20000 non-null  int64
#  46  region_code                   19999 non-null  float64
#  47  NetBanking_Flag               20000 non-null  int64
#  48  Avg_days_between_transaction  19997 non-null  float64
# dtypes: float64(27), int64(18), object(4)
# memory usage: 7.6+ MB

# %%
df.columns
# Out:
# Index(['ID', 'cc_cons', 'cc_cons_apr', 'dc_cons_apr', 'cc_cons_may',
#        'dc_cons_may', 'cc_cons_jun', 'dc_cons_jun', 'cc_count_apr',
#        'cc_count_may', 'cc_count_jun', 'dc_count_apr', 'dc_count_may',
#        'dc_count_jun', 'card_lim', 'personal_loan_active',
#        'vehicle_loan_active', 'personal_loan_closed', 'vehicle_loan_closed',
#        'investment_1', 'investment_2', 'investment_3', 'investment_4',
#        'debit_amount_apr', 'credit_amount_apr', 'debit_count_apr',
#        'credit_count_apr', 'max_credit_amount_apr', 'debit_amount_may',
#        'credit_amount_may', 'credit_count_may', 'debit_count_may',
#        'max_credit_amount_may', 'debit_amount_jun', 'credit_amount_jun',
#        'credit_count_jun', 'debit_count_jun', 'max_credit_amount_jun',
#        'loan_enq', 'emi_active', 'account_type', 'gender', 'age', 'Income',
#        'Emp_Tenure_Years', 'Tenure_with_Bank', 'region_code',
#        'NetBanking_Flag', 'Avg_days_between_transaction'],
#       dtype='object')

# %%
df.shape
# Out:
# (20000, 49)

# %%
df.nunique()
# Out:
# ID                              20000
# cc_cons                         12260
# cc_cons_apr                      8459
# dc_cons_apr                      3861
# cc_cons_may                      8504
# dc_cons_may                      4053
# cc_cons_jun                      7347
# dc_cons_jun                      3019
# cc_count_apr                       50
# cc_count_may                       58
# cc_count_jun                       67
# dc_count_apr                       41
# dc_count_may                       39
# dc_count_jun                       54
# card_lim                          308
# personal_loan_active                1
# vehicle_loan_active                 1
# personal_loan_closed                1
# vehicle_loan_closed                 1
# investment_1                      691
# investment_2                      532
# investment_3                      246
# investment_4                      115
# debit_amount_apr                 8724
# credit_amount_apr                8153
# debit_count_apr                    63
# credit_count_apr                   31
# max_credit_amount_apr            5996
# debit_amount_may                 8576
# credit_amount_may                8144
# credit_count_may                   31
# debit_count_may                    57
# max_credit_amount_may            5299
# debit_amount_jun                 8632
# credit_amount_jun                8311
# credit_count_jun                   39
# debit_count_jun                    66
# max_credit_amount_jun            5833
# loan_enq                            1
# emi_active                       5940
# account_type                        2
# gender                              2
# age                                43
# Income                              3
# Emp_Tenure_Years                  270
# Tenure_with_Bank                   10
# region_code                       210
# NetBanking_Flag                     2
# Avg_days_between_transaction       19
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include = ['float64', 'int64']).columns
object_columns = df.select_dtypes(include = ['object']).columns

# %%
df[object_columns].head(2)
# Out:
#   loan_enq account_type gender  Income
# 0        Y      current      M  MEDIUM
# 1        Y      current      M    HIGH

# %%
numeric_columns
# Out:
# Index(['ID', 'cc_cons', 'cc_cons_apr', 'dc_cons_apr', 'cc_cons_may',
#        'dc_cons_may', 'cc_cons_jun', 'dc_cons_jun', 'cc_count_apr',
#        'cc_count_may', 'cc_count_jun', 'dc_count_apr', 'dc_count_may',
#        'dc_count_jun', 'card_lim', 'personal_loan_active',
#        'vehicle_loan_active', 'personal_loan_closed', 'vehicle_loan_closed',
#        'investment_1', 'investment_2', 'investment_3', 'investment_4',
#        'debit_amount_apr', 'credit_amount_apr', 'debit_count_apr',
#        'credit_count_apr', 'max_credit_amount_apr', 'debit_amount_may',
#        'credit_amount_may', 'credit_count_may', 'debit_count_may',
#        'max_credit_amount_may', 'debit_amount_jun', 'credit_amount_jun',
#        'credit_count_jun', 'debit_count_jun', 'max_credit_amount_jun',
#        'emi_active', 'age', 'Emp_Tenure_Years', 'Tenure_with_Bank',
#        'region_code', 'NetBanking_Flag', 'Avg_days_between_transaction'],
#       dtype='object')

# %%
# Separate continous and categorical values
df_conti_vars = df.select_dtypes(include = ['float64', 'int64'])
df_cat_vars = df.select_dtypes(include = ['object'])

# %%
# alternate of .describe() for continuous variables
df_conti_vars.apply( continuous_var_summary ).round(1)

# cars_conti_vars.apply( lambda x: continuous_var_summary(x)).round(1)
# Out:
#                       ID            cc_cons      cc_cons_apr  \
# dtype              int64            float64          float64
# cardinality        20000              12260             8459
# n_tot              20000              20000            20000
# n                  20000              15000            20000
# nmiss                  0               5000                0
# perc_miss            0.0               25.0              0.0
# sum            199990000        827365948.0     357139818.44
# mean              9999.5       55157.729867     17856.990922
# std          5773.647028       97670.972252     25158.878234
# var           33335000.0  9539618820.721489  632969153.98808
# lc_iqr           -9999.5         -13238.625         -20841.0
# uc_iqr           29998.5          40112.375          46407.0
# min                    0                0.0            253.0
# p1                199.99             271.99         641.9886
# p5                999.95            1290.85           1219.0
# p10               1999.9             2633.6           1908.0
# p25              4999.75             6768.0           4377.0
# p50               9999.5            13364.0       10214.6425
# p75             14999.25           20105.75          21189.0
# p90              17999.1           219688.7          40640.9
# p95             18999.05           309852.0        59106.728
# p99             19799.01          395290.55         125259.5
# max                19999           408382.0        441031.33
#
#                   dc_cons_apr       cc_cons_may       dc_cons_may  \
# dtype                 float64           float64           float64
# cardinality              3861              8504              4053
# n_tot                   20000             20000             20000
# n                       20000             19999             20000
# nmiss                       0                 1                 0
# perc_miss                 0.0             0.005               0.0
# sum              162609068.27      323751105.97      154048543.82
# mean              8130.453414      16188.364717       7702.427191
# std              14572.188829      26510.681596        17892.7318
# var          212348687.260089  702816238.690255  320149851.281652
# lc_iqr              -9946.905       -18893.1825         -8309.735
# uc_iqr              20910.575        41184.3975         18207.585
# min                     19.35             157.0              22.0
# p1                   153.1286            509.49             152.1
# p5                      378.0          1035.774            410.97
# p10                    643.85          1666.328             731.0
# p25                   1624.65           3635.91           1634.26
# p50                   3964.75           8635.23           3791.72
# p75                   9339.02         18655.305           8263.59
# p90                 18443.691         36139.588          16144.76
# p95                   27835.0          53962.38           25584.0
# p99                  64470.75        125735.433        65963.0603
# max                  229255.0        1117246.31         911223.49
#
#                   cc_cons_jun       dc_cons_jun cc_count_apr cc_count_may  \
# dtype                 float64           float64      float64        int64
# cardinality              7347              3019           50           58
# n_tot                   20000             20000        20000        20000
# n                       20000             19999        19999        20000
# nmiss                       0                 1            1            0
# perc_miss                 0.0             0.005        0.005          0.0
# sum              242716120.41      142187057.12     832191.0       671382
# mean             12135.806021       7109.708341    41.611631      33.5691
# std              18790.984789      13313.935609    97.835475    50.316925
# var          353101109.329598  177260881.388224  9571.780105  2531.792915
# lc_iqr           -13795.90375          -7785.48        -53.5        -44.5
# uc_iqr            30990.70625           16605.4        102.5         95.5
# min                      65.0              62.0          1.0            1
# p1                      334.0            190.95          1.0          1.0
# p5                    825.101             390.0          1.0          2.0
# p10                   1367.52             607.0          2.0          3.0
# p25                  2999.075            1361.1          5.0          8.0
# p50                    6656.8            3326.0         10.0         23.0
# p75                14195.7275           7458.82         44.0         43.0
# p90                26791.1665           15689.0         80.0         83.0
# p95                39979.6775          24252.88        124.0         93.0
# p99                  90310.08           72564.0        531.0        128.0
# max                  382914.1          233384.0        531.0          601
#
#              ... credit_count_jun debit_count_jun max_credit_amount_jun  \
# dtype        ...            int64           int64               float64
# cardinality  ...               39              66                  5833
# n_tot        ...            20000           20000                 20000
# n            ...            20000           20000                 20000
# nmiss        ...                0               0                     0
# perc_miss    ...              0.0             0.0                   0.0
# sum          ...           398109          890582         1056996951.42
# mean         ...         19.90545         44.5291          52849.847571
# std          ...        27.055323       35.080453         134317.525107
# var          ...        731.99051     1230.638185    18041197550.945351
# lc_iqr       ...            -21.5           -79.5             -32762.25
# uc_iqr       ...             46.5           164.5             105175.75
# min          ...                1               0                  0.06
# p1           ...              1.0             0.0                 160.0
# p5           ...              2.0             2.0                1679.5
# p10          ...              2.0             7.0               11200.0
# p25          ...              4.0            12.0               18964.5
# p50          ...              7.0            37.0               30250.0
# p75          ...             21.0            73.0               53449.0
# p90          ...             58.0           103.0              100183.0
# p95          ...             94.0           106.0             150006.83
# p99          ...            117.0           124.0              377905.0
# max          ...              117             133             5200000.0
#
#                      emi_active         age Emp_Tenure_Years Tenure_with_Bank  \
# dtype                   float64       int64          float64            int64
# cardinality                5940          43              270               10
# n_tot                     20000       20000            20000            20000
# n                         19999       20000            20000            20000
# nmiss                         1           0                0                0
# perc_miss                 0.005         0.0              0.0              0.0
# sum                 307961976.6      953446         304345.0           109921
# mean               15398.868773     47.6723         15.21725          5.49605
# std               120254.075769   30.359771        20.481455         2.870452
# var          14461042739.004253  921.715698       419.489979         8.239496
# lc_iqr               -10199.735         3.0           -14.25             -4.5
# uc_iqr                21122.065        83.0            37.35             15.5
# min                         0.0          25              0.5                1
# p1                       26.739        27.0              0.9              1.0
# p5                       197.95        28.0              1.7              1.0
# p10                      461.06        29.0              2.7              2.0
# p25                     1545.94        33.0              5.1              3.0
# p50                     3934.66        40.0              9.9              6.0
# p75                     9376.39        53.0             18.0              8.0
# p90                   19715.252        64.0             31.5             10.0
# p95                    36148.07        66.0             40.0             10.0
# p99                  155041.219       222.0            121.2             10.0
# max                  7447125.13         223            203.0               10
#
#               region_code NetBanking_Flag Avg_days_between_transaction
# dtype             float64           int64                      float64
# cardinality           210               2                           19
# n_tot               20000           20000                        20000
# n                   19999           20000                        19997
# nmiss                   1               0                            3
# perc_miss           0.005             0.0                        0.015
# sum            11978588.0           14360                     220862.0
# mean           598.959348           0.718                    11.044757
# std             220.10523        0.449985                     5.480552
# var          48446.312129        0.202486                    30.036454
# lc_iqr             -138.5            -1.5                         -9.0
# uc_iqr             1361.5             2.5                         31.0
# min                 123.0               0                          2.0
# p1                  233.0             0.0                          2.0
# p5                  249.0             0.0                          2.0
# p10                 269.0             0.0                          3.0
# p25                 424.0             0.0                          6.0
# p50                 623.0             1.0                         11.0
# p75                 799.0             1.0                         16.0
# p90                 883.0             1.0                         19.0
# p95                 937.0             1.0                         20.0
# p99                 968.0             1.0                         20.0
# max                 974.0               1                         20.0
#
# [23 rows x 45 columns]

# %%
df_cat_vars.apply(categorical_var_summary)
# Out:
#         loan_enq account_type gender  Income
# N          19998        19999  19999   19999
# NMISS          2            1      1       1
# MODE           Y      current      M  MEDIUM
# FREQ       19998        16925  17287   12774
# PERCENT    100.0        84.63  86.44   63.87

# %%
df.loan_enq = pd.Categorical(df.loan_enq).codes
df.account_type = pd.Categorical(df.account_type).codes
df.gender = pd.Categorical(df.gender).codes
df.Income = pd.Categorical(df.Income).codes

# %%
df.head(3)
# Out:
#       ID  cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0  12554  20014.0     24893.00        378.0      10288.0     29664.00
# 1  17645  10173.0     18941.62        966.0      20672.0       287.00
# 2   7604  16095.0      5678.87       2724.0       1964.5      3933.11
#
#    cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  emi_active  \
# 0     16291.40      11432.0           2.0            26  ...     1674.09
# 1      4217.00        885.0           1.0             7  ...    13043.34
# 2     23956.25       5168.0          43.0            32  ...    25375.27
#
#    account_type  gender  age  Income  Emp_Tenure_Years  Tenure_with_Bank  \
# 0             0       1   35       2              15.0                 1
# 1             0       1   35       0              15.0                 6
# 2             0       1   55       2              24.5                 1
#
#    region_code  NetBanking_Flag  Avg_days_between_transaction
# 0        708.0                0                          17.0
# 1        123.0                0                          14.0
# 2        802.0                1                           3.0
#
# [3 rows x 49 columns]

# %%
df_conti_vars.isna().sum() * 100 / df_conti_vars.isna().count()
# Out:
# ID                               0.000
# cc_cons                         25.000
# cc_cons_apr                      0.000
# dc_cons_apr                      0.000
# cc_cons_may                      0.005
# dc_cons_may                      0.000
# cc_cons_jun                      0.000
# dc_cons_jun                      0.005
# cc_count_apr                     0.005
# cc_count_may                     0.000
# cc_count_jun                     0.000
# dc_count_apr                     0.000
# dc_count_may                     0.000
# dc_count_jun                     0.000
# card_lim                         0.000
# personal_loan_active             0.000
# vehicle_loan_active              0.000
# personal_loan_closed             0.005
# vehicle_loan_closed              0.000
# investment_1                     0.000
# investment_2                     0.000
# investment_3                     0.010
# investment_4                     0.000
# debit_amount_apr                 0.000
# credit_amount_apr                0.000
# debit_count_apr                  0.005
# credit_count_apr                 0.000
# max_credit_amount_apr            0.000
# debit_amount_may                 0.000
# credit_amount_may                0.000
# credit_count_may                 0.000
# debit_count_may                  0.000
# max_credit_amount_may            0.000
# debit_amount_jun                 0.000
# credit_amount_jun                0.000
# credit_count_jun                 0.000
# debit_count_jun                  0.000
# max_credit_amount_jun            0.000
# emi_active                       0.005
# age                              0.000
# Emp_Tenure_Years                 0.000
# Tenure_with_Bank                 0.000
# region_code                      0.005
# NetBanking_Flag                  0.000
# Avg_days_between_transaction     0.015
# dtype: float64

# %%
plt.figure(figsize=(12,4))
sns.heatmap(df.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('Missing value in the dataset');

# %%
train = df[~df.cc_cons.isna()]
test =df[df.cc_cons.isna()]

# %%
y_test = df[df['cc_cons'].isnull()]['cc_cons']
y_train = df[~df['cc_cons'].isnull()]['cc_cons']


print(y_test)
print(y_train)

x_train = df[~df['cc_cons'].isnull()]
x_test = df[df['cc_cons'].isnull()]

print(x_train)
print(x_test)
# Out:
# 15000   NaN
# 15001   NaN
# 15002   NaN
# 15003   NaN
# 15004   NaN
#          ..
# 19995   NaN
# 19996   NaN
# 19997   NaN
# 19998   NaN
# 19999   NaN
# Name: cc_cons, Length: 5000, dtype: float64
# 0         20014.0
# 1         10173.0
# 2         16095.0
# 3          7707.0
# 4         96408.0
#            ...
# 14995      4263.0
# 14996     11019.0
# 14997    404227.0
# 14998     28813.0
# 14999     16252.0
# Name: cc_cons, Length: 15000, dtype: float64
#           ID   cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0      12554   20014.0     24893.00       378.00     10288.00     29664.00
# 1      17645   10173.0     18941.62       966.00     20672.00       287.00
# 2       7604   16095.0      5678.87      2724.00      1964.50      3933.11
# 3       1590    7707.0     30489.50      1236.00     12609.88      9138.14
# 4      16556   96408.0      7441.40      6906.04      4364.00      1939.00
# ...      ...       ...          ...          ...          ...          ...
# 14995   6995    4263.0     10443.76      1218.85      7252.24      3873.00
# 14996  10376   11019.0     29890.33      6308.00     16025.50      7610.00
# 14997   2181  404227.0      4148.98       948.74     19360.26       494.00
# 14998  18417   28813.0    115574.00      7191.05     44341.13     34817.20
# 14999   4547   16252.0      7375.67       306.80      5859.49      6702.40
#
#        cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  emi_active  \
# 0         16291.40     11432.00           2.0            26  ...     1674.09
# 1          4217.00       885.00           1.0             7  ...    13043.34
# 2         23956.25      5168.00          43.0            32  ...    25375.27
# 3         17521.00     13650.30          53.0             1  ...     3544.33
# 4          2121.00      6829.18          67.0            47  ...    12780.44
# ...            ...          ...           ...           ...  ...         ...
# 14995      6633.00     10107.00           3.0            36  ...    78966.76
# 14996      2213.08       841.60           1.0            34  ...     4762.10
# 14997     44363.91      1801.77          57.0            23  ...     2877.33
# 14998     20679.00      1010.00           7.0           128  ...    13006.84
# 14999     33211.65       263.00          28.0            71  ...     1588.60
#
#        account_type  gender  age  Income  Emp_Tenure_Years  Tenure_with_Bank  \
# 0                 0       1   35       2              15.0                 1
# 1                 0       1   35       0              15.0                 6
# 2                 0       1   55       2              24.5                 1
# 3                 0       0   29       2               4.5                 6
# 4                 0       1   34       2              12.6                 4
# ...             ...     ...  ...     ...               ...               ...
# 14995             0       0   53       1              13.2                 9
# 14996             0       1   44       2               2.4                 9
# 14997             0       1   37       2               3.4                 9
# 14998             0       1  220       2              40.0                10
# 14999             0       1   66       2               4.6                 2
#
#        region_code  NetBanking_Flag  Avg_days_between_transaction
# 0            708.0                0                          17.0
# 1            123.0                0                          14.0
# 2            802.0                1                           3.0
# 3            867.0                1                           4.0
# 4            802.0                1                           7.0
# ...            ...              ...                           ...
# 14995        653.0                1                          20.0
# 14996        535.0                1                           2.0
# 14997        464.0                1                           8.0
# 14998        536.0                1                           3.0
# 14999        269.0                0                           8.0
#
# [15000 rows x 49 columns]
#           ID  cc_cons  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 15000  17591      NaN     2795.450      1290.00      6141.05       676.50
# 15001  13541      NaN    29405.130      1640.00      1670.00      2463.92
# 15002  13431      NaN     5985.200      6189.00      2696.09       766.00
# 15003   8687      NaN     2105.930     18225.00     34763.56       167.00
# 15004  14727      NaN     3269.000      3532.00      3158.40      2699.77
# ...      ...      ...          ...          ...          ...          ...
# 19995  12512      NaN     4641.500      5979.58      6008.61      4410.00
# 19996  14224      NaN     4994.450      2805.37     23214.00      5870.00
# 19997  18740      NaN     3262.145      2871.00      7335.25     11774.04
# 19998  18134      NaN    12824.010      4866.00     12242.48       284.00
# 19999  12413      NaN    26218.000      6615.00      2832.00      4642.00
#
#        cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  emi_active  \
# 15000      9146.10     15479.00           4.0            10  ...     1170.49
# 15001     10947.50       956.00           3.0            10  ...    16447.45
# 15002       716.00      4133.22           7.0            30  ...     2622.28
# 15003      4260.27     20185.00           1.0            99  ...      340.79
# 15004      3373.48      5120.00           2.0            10  ...     2812.20
# ...            ...          ...           ...           ...  ...         ...
# 19995     41743.00      1884.00          26.0             1  ...     7870.88
# 19996      1041.00      1008.73          37.0            56  ...     3668.30
# 19997      4130.00      1413.00          12.0            77  ...     5450.34
# 19998     15132.77     37911.00          67.0             1  ...       59.29
# 19999      1314.64     11355.00           7.0             1  ...      793.41
#
#        account_type  gender  age  Income  Emp_Tenure_Years  Tenure_with_Bank  \
# 15000             0       1   37       2              11.9                 4
# 15001             0       1   33       2               7.8                 6
# 15002             0       1   53       1              33.0                10
# 15003             0       1   33       2               7.8                 5
# 15004             0       1   62       1              12.6                 9
# ...             ...     ...  ...     ...               ...               ...
# 19995             0       1   35       2              13.5                 1
# 19996             0       1   53       2               9.9                 7
# 19997             0       1   62       0              37.8                 8
# 19998             0       1   34       2              12.6                 4
# 19999             0       1   27       1               3.5                 8
#
#        region_code  NetBanking_Flag  Avg_days_between_transaction
# 15000        575.0                1                          16.0
# 15001        394.0                0                          19.0
# 15002        324.0                1                          15.0
# 15003        370.0                1                           7.0
# 15004        505.0                1                           3.0
# ...            ...              ...                           ...
# 19995        523.0                0                           7.0
# 19996        723.0                1                           2.0
# 19997        863.0                1                          16.0
# 19998        882.0                0                          13.0
# 19999        447.0                1                           NaN
#
# [5000 rows x 49 columns]

# %%
#missing data - x_train
total = x_train.isnull().sum().sort_values(ascending=False)
percent = (x_train.isnull().sum()/x_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#                               Total   Percent
# investment_3                      2  0.000133
# Avg_days_between_transaction      1  0.000067
# cc_count_apr                      1  0.000067
# personal_loan_closed              1  0.000067
# emi_active                        1  0.000067
# debit_count_apr                   1  0.000067
# Income                            0  0.000000
# age                               0  0.000000
# debit_amount_may                  0  0.000000
# credit_amount_may                 0  0.000000
# credit_count_may                  0  0.000000
# NetBanking_Flag                   0  0.000000
# debit_count_may                   0  0.000000
# max_credit_amount_may             0  0.000000
# debit_amount_jun                  0  0.000000
# region_code                       0  0.000000
# credit_amount_jun                 0  0.000000
# credit_count_jun                  0  0.000000
# debit_count_jun                   0  0.000000
# max_credit_amount_apr             0  0.000000
# loan_enq                          0  0.000000
# Tenure_with_Bank                  0  0.000000
# account_type                      0  0.000000
# gender                            0  0.000000
# Emp_Tenure_Years                  0  0.000000

# %%
x_train.isna().sum().sum()
# Out:
# 7

# %%
#missing data - x_train
total = x_test.isnull().sum().sort_values(ascending=False)
percent = (x_test.isnull().sum()/x_test.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#                               Total  Percent
# cc_cons                        5000   1.0000
# Avg_days_between_transaction      2   0.0004
# region_code                       1   0.0002
# cc_cons_may                       1   0.0002
# dc_cons_jun                       1   0.0002
# debit_count_jun                   0   0.0000
# debit_amount_may                  0   0.0000
# credit_amount_may                 0   0.0000
# credit_count_may                  0   0.0000
# debit_count_may                   0   0.0000
# max_credit_amount_may             0   0.0000
# debit_amount_jun                  0   0.0000
# credit_amount_jun                 0   0.0000
# credit_count_jun                  0   0.0000
# loan_enq                          0   0.0000
# max_credit_amount_jun             0   0.0000
# credit_count_apr                  0   0.0000
# emi_active                        0   0.0000
# account_type                      0   0.0000
# gender                            0   0.0000
# age                               0   0.0000
# Income                            0   0.0000
# Emp_Tenure_Years                  0   0.0000
# Tenure_with_Bank                  0   0.0000
# NetBanking_Flag                   0   0.0000

# %%
x_test.isna().sum().sum()
# Out:
# 5005

# %%
#missing data - y_train
y_train.isna().sum()
# Out:
# 0

# %%
x_train.shape
# Out:
# (15000, 49)

# %%
x_train = x_train.apply(missing_imputation)

# %%
x_train.isna().sum().sum()
# Out:
# 0

# %%
y_train.shape
# Out:
# (15000,)

# %%
x_train = x_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
y_train = y_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
x_test = x_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
y_test = y_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
x_test.shape
# Out:
# (5000, 49)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# -1.2369127944111824e-10

# %%
print(model.coef_)
# Out:
# [-1.54120366e-15  1.00000000e+00  4.76702011e-15 -2.19269047e-15
#   4.55191440e-15  8.25034485e-15 -4.27435864e-15 -2.31481501e-14
#   1.07065745e-12  1.25082995e-12  5.63599121e-13  1.73421967e-12
#  -1.16102665e-12  5.65326960e-13  3.88578059e-16  1.73472348e-17
#   2.77555756e-17 -2.77555756e-17  1.11022302e-16  0.00000000e+00
#  -1.66533454e-16 -2.66453526e-15  7.91033905e-16  1.08246745e-15
#   2.77555756e-17 -1.20157078e-14 -1.16499912e-14 -4.16333634e-17
#   3.05311332e-16 -1.66533454e-16  3.97261840e-15 -1.07685670e-15
#   1.11022302e-16 -1.52655666e-16  4.16333634e-17  3.30033852e-15
#   7.76928435e-15  3.60822483e-16  6.88957536e-11  7.77156117e-16
#  -2.50362257e-13  5.40738519e-13 -6.46783855e-15 -4.50523985e-13
#   5.86962662e-15  6.23530300e-14  1.31777998e-15 -2.33441767e-13
#   3.66712327e-14]

# %%
from sklearn import metrics

# %%
predictions = model.predict(x_test)
predictions= predictions.reshape(-1,1)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.361896781824999e-10
# MSE: 2.7108949294484293e-19
# RMSE: 5.206625518940679e-10
